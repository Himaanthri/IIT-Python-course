# %%
print('Hi IIT')
# Out:
# Hi IIT

# %% [markdown]
# ## Variable Declaration and Verification

# %%
x=10
y='Sri Lanka'
z=10.08
print(x)
print(y)
print(z)
# Out:
# 10
# Sri Lanka
# 10.08

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
print(type(z))
# Out:
# <class 'float'>

# %%
X=100
print(X)
# Out:
# 100

# %% [markdown]
# ### Arithmetic Operators

# %%
5+2
# Out:
# 7

# %%
5-2
# Out:
# 3

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
 5//2
# Out:
# 2

# %%
5%2
# Out:
# 1

# %%
5**2
# Out:
# 25

# %% [markdown]
# ## Assignment Operators

# %%
a=5
b=2
a=b
print(a)
# Out:
# 2

# %%
a=5
b=2
a+=b
#a+b
print(a)
# Out:
# 7

# %%
a=5
b=2
a-=b
#a-b
print(a)
# Out:
# 3

# %%
a=5
b=2
a*=b
#a*b
print(a)
# Out:
# 10

# %%
a=5
b=2
a/=b
#a/b
print(a)
# Out:
# 2.5

# %%
a=5
b=2
a//=b
#a//b
print(a)
# Out:
# 2

# %%
a=5
b=2
a%=b
#a%b
print(a)
# Out:
# 1

# %%
a=5
b=2
a**=b
#a**b
print(a)
# Out:
# 25

# %% [markdown]
# ## Comparison Operators

# %%
a=5
b=2
a==b
# Out:
# False

# %%
a=5
b=2
a!=b
# Out:
# True

# %%
a=5
b=2
a>b
# Out:
# True

# %%
a=5
b=2
a<b
# Out:
# False

# %%
a=5
b=2
a>=b
# Out:
# True

# %%
a=5
b=2
a<=b
# Out:
# False

# %% [markdown]
# ## Logical operators

# %% [markdown]
# ### NOT

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### AND

# %%
True and True
# Out:
# True

# %%
False and True
# Out:
# False

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %% [markdown]
# ### OR

# %%
True or True
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
print("Done")
# Out:
# Done
