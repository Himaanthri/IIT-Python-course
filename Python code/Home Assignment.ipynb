# %%
name = input("What is your name?")
mark = int(input("What is your marks?"))
if 100 >= mark>80:
    print("A")
elif 80 >= mark > 60:
    print("B")
elif 60>= mark >=40:
    print("C")
elif 40> mark >= 0:
    print("Fail")
else:
    print("Invalid")
# Out:
# What is your name? j
# What is your marks? 120
# Invalid
