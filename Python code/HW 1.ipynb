# %% [markdown]
# # Homework - Week 01

# %% [markdown]
# ## Writing codes

# %% [markdown]
# ### Introduction of 'print' command

# %%
print("Hi IIT")
# Out:
# Hi IIT

# %%
print('This is Himaanthri Surendran')
# Out:
# This is Himaanthri Surendran
