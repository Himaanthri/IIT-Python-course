# %% [markdown]
# ### IIT Python

# %% [markdown]
# ## Week 01

# %% [markdown]
# # First Command - print

# %%
print("Hi Everyone")
# Out:
# Hi Everyone

# %%
Print("Hi")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Print("Hi")
#
# NameError: name 'Print' is not defined

# %%
print('Hi')
# Out:
# Hi

# %%
print("My name is Himaanthri Surendran")
# Out:
# My name is Himaanthri Surendran

# %%
print("I am a Credit Analyst at Seylan Bank PLC")
# Out:
# I am a Credit Analyst at Seylan Bank PLC

# %%
print("I am learning Python Programming")
# Out:
# I am learning Python Programming

# %%
print("I am currently learning ML")
# Out:
# I am currently learning ML

# %%
print("My name is Himaanthri Surendran \nI am a Credit Analyst at Seylan Bank PLC \nI am learning Python Programming \nI am currently learning ML")
# Out:
# My name is Himaanthri Surendran
# I am a Credit Analyst at Seylan Bank PLC
# I am learning Python Programming
# I am currently learning ML

# %%
#ABC

# %% [markdown]
# #ABC

# %% [markdown]
# ## ABC

# %% [markdown]
# ### ABC
