# %%
age = int(input("How old are you?"))
if age>18:
    print("Adult")
else:
    print("Minor")
# Out:
# How old are you? 18
# Adult

# %%
marks = int(input("What's your marks?"))
score = marks
if score>50:
    print("Pass")
else:
    print("Fail")
# Out:
# What's your marks? 100
# Pass

# %%
marks = int(input("What's your marks?"))
if marks>=75:
    print("Grade A")
elif marks>=65:
    print("Grade B")
elif marks>=50:
    print("Grade C")
else:
     print("Grade F")
# Out:
# What's your marks? 100
# Grade A

# %%
marks = int(input("What's your marks?"))
if marks>=75:
    print("Grade A")
else:
    if marks>=65:
        print("Grade B")
    else:
        if marks>=50:
            print("Grade C")
        else:
             print("Grade F")
# Out:
# What's your marks? 100
# Grade A

# %%
age = int(input("Enter your age"))
if age>=18:
    print("You're eligible to vote")
else:
    print("You're not eligible to vote")
# Out:
# Enter your age 24
# You're eligible to vote

# %%
num = int(input("Give me a number"))
if num % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Give me a number 23
# Odd

# %%
num = int(input("Give me a number"))
if num % 2 != 0:
    print("Odd")
else:
    print("Even")
# Out:
# Give me a number 24
# Even

# %%
num = int(input("Give me a number"))
if num % 2 == 1:
    print("Odd")
else:
    print("Even")
# Out:
# Give me a number 100
# Even

# %%
num = int(input("Give me a number"))
if num % 2 != 1:
    print("Even")
else:
    print("Odd")
# Out:
# Give me a number -100
# Even

# %%
Name = input("What's your name?")
Marks = int(input("What's your marks?"))
if 100>=Marks>=75:
    Grade = "A"
elif 75>Marks>=65:
    Grade = "B"
elif 65>Marks>=50:
    Grade = "C"
else:
    Grade = "F"
print("Name           Marks    Grade")
print(Name,"    ",Marks,"    ",Grade)
# Out:
# What's your name? Himaanthri
# What's your marks? 100
# Name           Marks    Grade
# Himaanthri      100      A

# %%
Name = input("What's your name?")
Marks = int(input("What's your marks?"))
print("Name           Marks    Grade")
if 100>=Marks>=75:
    print(Name,"    ",Marks,"    Grade A")
else:
    if Marks>=65:
        print(Name,"    ",Marks,"    Grade B")
    else:
        if Marks>=50:
            print(Name,"    ",Marks,"    Grade C")
        else:
            print(Name,"    ",Marks,"    Grade F")
# Out:
# What's your name? Himaanthri
# What's your marks? 87
# Himaanthri      87     Grade A

# %%
x = 10
y = 20
if x>5:
    if y>15:
        print("Both conditions are true")
    else:
        print("Only x>5 is true")
else:
    print("x is not greater than 5")
# Out:
# Both conditions are true

# %%
num = int(input("Enter a number"))
if num>0:
    print("Positive number")
elif num<0:
    print("Negative number")
else:
    print("Zero")
# Out:
# Enter a number +0
# Zero

# %%
Name = input("What's your name?")
Marks = int(input("What's your marks?"))
if 100>=Marks and Marks>=90:
    Grade = "A"
elif 90>Marks>=80:
    Grade = "B"
elif 80>Marks>=70:
    Grade = "C"
elif 70>Marks>=60:
    Grade = "D"
elif 60>Marks and Marks>=0:
    Grade = "F"
else:
    Grade = "Invalid"
print("Name           Marks    Grade")
print(Name,"    ",Marks,"    ",Grade)
# Out:
# What's your name? Himaanthri
# What's your marks? 100
# Name           Marks    Grade
# Himaanthri      100      A
